# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Wasil/GenAI-Internship-Training-Program/blob/main/converters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kmToMiles(km):
    return float(km) * 0.621371
def celsiusToFahrenheit(celsius):
    return celsius * 9/5 + 32
def kgToLbs(kg):
    return kg * 2.20462

def bmi(kg, height):
    return kg / (height * height)

weight=float(input("enter weight in kg : "))
print(kgToLbs(weight),"pounds")
height=float(input("enter height in meters : "))
print("BMI is : ",bmi(weight, height))
distance=float(input("Enter distance(km): "))
print(kmToMiles(distance),"miles")
temp=float(input("enter temperature in celsius: "))
print(celsiusToFahrenheit(temp),"Fahrenheit")
# Out:
# enter weight in kg : 72.3
# 159.39402599999997 pounds
# enter height in meters : 1.6764
# BMI is :  25.726635475309518
# Enter distance(km): 75
# 46.602825 miles
# enter temperature in celsius: 33.3
# 91.94 Fahrenheit
