# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Wasil/GenAI-Internship-Training-Program/blob/main/word_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
para=input("enter a paragraph : ")
words=para.split()
wordCount={}
for i in words:
    if i in wordCount:
        wordCount[i]+=1
    else:
        wordCount[i]=1
print(wordCount)
# Out:
# enter a paragraph : Hello. Today is Wednesday. Today is my first day at work. I am  enjoying it very much.Thank you
# {'Hello.': 1, 'Today': 2, 'is': 2, 'Wednesday.': 1, 'my': 1, 'first': 1, 'day': 1, 'at': 1, 'work.': 1, 'I': 1, 'am': 1, 'enjoying': 1, 'it': 1, 'very': 1, 'much.Thank': 1, 'you': 1}
