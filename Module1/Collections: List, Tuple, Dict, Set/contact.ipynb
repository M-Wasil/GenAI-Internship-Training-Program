# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Wasil/GenAI-Internship-Training-Program/blob/main/contact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contactList={
    "Wasil": 923111978797,
    "Ali": 923111978798,
    "Ahmed": 923111978799
}
print(contactList.values())
name=input("enter name : ")
if name in contactList:
    print("Phone Number : ",contactList[name])
else:
    print("Contact not found")
# Out:
# dict_values([923111978797, 923111978798, 923111978799])
# enter name : Wasil
# Phone Number :  923111978797
